# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahelo14/Programa-o-e-algorit-mo-PA/blob/main/25_03marcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Decisões

# Entrada
a = int (input("digitar um número: "))
b = int (input("digitar um número: "))


if a > b:

  print (f"{a} é maior que {b}.")

else:

  print (f"{b} é maior que {a}.")
# Out:
# digitar um número: 9
# digitar um número: 10
# 10 é maior que 9.

# %%
# Escrever um programa que recebe 04 notas do aluno, calcula a média e mostra se o aluno foi aprovado.


# Entrada

nota1 = float (input("digite a nota do 1º bimestre"))
nota2 = float (input("digite a nota do 2º bimestre"))
nota3 = float (input("digite a nota do 3º bimestre"))
nota4 = float (input("digite a nota do 4º bimestre"))

# Processamento

resultado = (nota1 + nota2 + nota3 + nota4) / 4

if resultado >= 7:

 print (f"A média das suas notas foi {resultado}, você foi aprovado.")

elif resultado >= 5:

   print (f"A média das suas notas foi {resultado}, você terá que fazer recuperação.")

else:

   print (f"A média das suas notas foi {resultado}, você foi reprovado.")

# Saída
# Out:
# digite a nota do 1º bimestre 8
# digite a nota do 2º bimestre9
# digite a nota do 3º bimestre10
# digite a nota do 4º bimestre10
# A média das suas notas foi 9.25, você foi aprovado.

# %%
# Fazer uma calculadora simples com as 04 operações

print ("---------------- MENU ------------- ")
print("")
print(" Opção - 1 = SOMA")
print(" Opção - 2 = SUBTRAÇÃO")
print(" Opção - 3 = MULTIPLICAÇÃO")
print(" Opção - 4 = DIVISÃO")
print("")

opcao = int (input("Digite a opção: "))

# Entrada
numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Digite o segundo número: "))

if opcao == 1:
  resultado = numero1 + numero2
  print(f" o resultado é {resultado}")

elif opcao == 2:
  resultado = numero1 - numero2
  print(f"o resultado é {resultado}")

elif opcao == 3:
  resultado = numero1 * numero2
  print(f"o resultado é {resultado}")

elif opcao == 4:
  resultado = numero1 / numero2
  print(f"o resultado é {resultado}")

else:
  print ("Opção inválida")
# Out:
# ---------------- MENU -------------
#
#  Opção - 1 = SOMA
#  Opção - 2 = SUBTRAÇÃO
#  Opção - 3 = MULTIPLICAÇÃO
#  Opção - 4 = DIVISÃO
#
# Digite a opção: 4
# Digite o primeiro número: 0
# Digite o segundo número: 7
# o resultado é 0.0
