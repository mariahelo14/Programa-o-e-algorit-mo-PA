# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahelo14/Programa-o-e-algorit-mo-PA/blob/main/20_05_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = ""

while senha != 1234:
  senha = int (input("Digite á senha: "))

print("Acesso permitido")
# Out:
# Digite á senha: 389
# Digite á senha: 1234
# Acesso permitido

# %%
# Escrever um programa que faz uma contagem regressiva de 10 até zero e imrpimi uma mensagem de "acabou" no final.

contador = 10

while contador >= 0:
  print (contador)

# %%
# Escrever um programa que recebe 04 notas do aluno, calcula a média e imprimi aprovado, recuperação ou reprovado.

# Regras:

# utilizar while
# nota maior ou igual a 7 aprovado
# nota maior ou igaul a 5 recuperação
# nota menor que 5 reprovado

notas = 0
bimestre = 1
soma = 0

while bimestre <= 4:
  notas = float (input(f"Digite sua nota do {bimestre}º bimestre: "))
  soma = soma + notas
  bimestre +=1


media_final = soma / 4

if media_final >= 7:
  print(f"A sua média final foi {media_final}, você está aprovado!")

elif media_final >= 5:
  print(f"A sua média final foi {media_final}, você está de recuperação!")

else:
  print(f"A sua média final foi {media_final}, você está reprovado!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36111/1119448011.py in <cell line: 0>()
#      13
#      14 while bimestre <= 4:
# ---> 15   notas = float (input(f"Digite sua nota do {bimestre}º bimestre: "))
#      16   soma = soma + notas
#      17   bimestre +=1
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# Calculadora simples
opcao=0

while opcao != 4:

  print("opção - 1 - Seja bem vindo")
  print("opção - 2 - Somar")
  print("opção - 3 - Subtrair")
  print("opção - 4 - Sair")

  opcao = int (input("Digite e a opção desejada: "))

  if opcao == 1:
    print ("Seja bem vindo")

  elif opcao == 2:
    a = int(input("Digite o primerio valor: "))
    b = int(input("Digite o segundo valor: "))
    print (f"Total da soma: {a+b}")

  elif opcao == 3:
    a = int(input("Digite o primerio valor: "))
    b = int(input("Digite o segundo valor: "))
    print (f"Total da subtração: {a+b}")
# Out:
# opção - 1 - Seja bem vindo
# opção - 2 - Somar
# opção - 3 - Subtrair
# opção - 4 - Sair
# Digite e a opção desejada: 2
# Digite o primerio valor: 4
# Digite o segundo valor: 2
# Total da soma: 6
# opção - 1 - Seja bem vindo
# opção - 2 - Somar
# opção - 3 - Subtrair
# opção - 4 - Sair

# %%
# Você foi contratado para desenvolver um sistema simples de caixa eletrônico.

# O sistema deverá funcionar através de um menu interativo utilizado a estrutura de repetição while.

# o programa deve iniciar com um saldo de R$ 1.000,00 e permitir que o usuário escolha difrentes operações até decidir sair do sistema.

# Funcionalidades:
