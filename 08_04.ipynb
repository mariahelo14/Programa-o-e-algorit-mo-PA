# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahelo14/Programa-o-e-algorit-mo-PA/blob/main/08_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa para identificar se um número é par ou ímpar

numero = int(input("Digite um número: "))

if numero % 2 == 0:
  print("o número é PAR")

else:
  print("o número é ÍMPAR")
# Out:
# Digite um número: 7
# o número é ÍMPAR

# %%
# Escrever um programa o usuário digita o nome e as suas 04 notas referentes aos bimestres, calcula a média e mostra se o aluno foi:
# aprovado, recuperação ou repprovado.

# nota maior ou igual a 7 aprovado;
# nota maior ou igual 5 e menor 7 recuperação;
# nota menor que 5 reprovado;


# Entrada

nome = str (input("Digite seu nome: "))
nota1 = float (input("Digite a sua nota do primeiro 1º bimestre: "))
nota2 = float (input("Digite a sua nota do primeiro 2º bimestre: "))
nota3 = float (input("Digite a sua nota do primeiro 3º bimestre: "))
nota4 = float (input("Digite a sua nota do primeiro 4º bimestre: "))

media = (nota1 + nota2 + nota3 + nota4) / 4

if media >= 7:
  print(f"{nome}", "Aprovado(a)")

elif media >= 5 and media < 7:
  print(f"{nome}", "Recuperação")

else:
  print(f"{nome}", "Reprovado(a)")
# Out:
# Digite seu nome: Maria
# Digite a sua nota do primeiro 1º bimestre: 7
# Digite a sua nota do primeiro 2º bimestre: 8
# Digite a sua nota do primeiro 3º bimestre: 9
# Digite a sua nota do primeiro 4º bimestre: 10
# Maria Aprovado(a)

# %%
# Escrever um programa que recebe os valores de 03 lados e verifica se é um triângulo válido
# E classifica o tipo de triângulo.

# Verificar se o triângulo é válido;
 # * a soma das médias de4 quaisquer dois lados deve ser sempre maior que a média do terceiro lado.

# Classificar tipos de triângulos;

# Equilatero - Todos os lados iguais
# Isoceles - Possui dois lados iguais
# Escaleno - Todos os diferentes

lado1 = int (input("Digite o primeiro lado do triângulo: "))

lado2 = int (input("Digite o segundo lado do triângulo: " ))

lado3 = int (input("Digite o terceiro lado do triângulo: "))

if (lado1 + lado2 > lado3) and (lado1 + lado2 + lado3) and (lado2 + lado3 > lado1):
  print("é um triângulo válido")

  if lado1 == lado2 and lado1 == lado3:
    print("é um triângulo equilátero")

  elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("é um triângulo equilátero")

  else:
    print("é um triângulo esacaleno")

else:
    print("não é um triângulo válido")
# Out:
# Digite o primeiro lado do triângulo: 2
# Digite o segundo lado do triângulo: 2
# Digite o terceiro lado do triângulo: 3
# é um triângulo válido
# é um triângulo equilátero
