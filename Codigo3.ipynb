# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahelo14/Programa-o-e-algorit-mo-PA/blob/main/Codigo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de progrmação e algoritímos
# *   Cáculculo de área
#
# # Entrada
#
# *   Ler lado1
# *   Ler lado2
# # processamento
# area = lado1 * lado2
# #Saída
# imprimir area

# %%
# Cálculo de área

# Entrada

lado_1 = 5

lado_2 = 4

nome = "Maria"

# %%
# Processameto

area = lado_1*lado_2

# %%
# Saída

print (f"total da área: {area}")
# Out:
# total da área: 20

# %%
python

# Tipos Numéricos
idade = 25 # int
altura = 1.75 # float
numero_complexo = 2 + 3j #complex

# Tipo Texto
nome = "Alice" # str

# Tipo Booleano
esta_chovendo = False #bool

# Tipo lista (mutável)
numeros = [1, 2, 3, 4, 5] # list

# Tipo Tupla (imutável)
coordenadas = (10, 20) #tuple

# Tipo Conjunto (valores únicos)
vogais = {'a', 'e', 'i', 'o', 'u'} # set

# Tipo Dicionário (chave-valor)
Pessoa
